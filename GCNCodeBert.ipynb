# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd DebtSniffer

# %%
# !pip install ignite
# !pip install transformers
# !pip install scikit-learn
# !pip install pytorch-ignite
# !pip install dgl-cu110

# %%
# !python build_graph.py SATD

# %%
# !python finetune_codebert.py --dataset SATD --nb_epochs 30 --max_length 64 --bert_init microsoft/codebert-base --checkpoint_dir codebert_SATD

# %%
# !python train_codebert_gcn.py --dataset SATD --nb_epochs 30 --max_length 64 --gcn_layers 2 --bert_lr 1e-5 --gcn_lr 1e-3 --bert_init microsoft/codebert-base --pretrained_bert_ckpt codebert_SATD/checkpoint.pth --checkpoint_dir codebert_gcn_SATD
